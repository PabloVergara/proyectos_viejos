# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
import seaborn as sns

from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
import numpy as np
from kmodes.kmodes import KModes

# random categorical data
data = np.random.choice(20, (1000, 10))
df = pd.DataFrame(data, dtype='str')
km = KModes(n_clusters=4, init='Huang', n_init=5, verbose=1)

clusters = km.fit_predict(data)

# Print the cluster centroids
print(km.cluster_centroids_)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 26, cost: 8672.0
# Run 1, iteration: 2/100, moves: 0, cost: 8672.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 8692.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 192, cost: 8670.0
# Run 3, iteration: 2/100, moves: 0, cost: 8670.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 33, cost: 8706.0
# Run 4, iteration: 2/100, moves: 0, cost: 8706.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 64, cost: 8663.0
# Run 5, iteration: 2/100, moves: 0, cost: 8663.0
# Best run was number 5
# [[15 12  5  7  1 14 18  3  8 13]
#  [ 5  7 19  1 17 11  2  7  5  7]
#  [18 15 11 13 10  4 11  7  5  6]
#  [11 10 12 15 14 16  0  0 18  9]]

# %%
colores=['blue','grey','red','black','green','yellow','magenta','cyan' ]
labels = km.labels_
asignar=[]
for fila in labels:
    asignar.append(colores[fila])

# %%
#Se necesitan headers
df['color']=asignar
df['2']=df[2]
df['1']=df[1]

# %%
facet = sns.lmplot(data=df, x='1', y='2', hue='color', 
                   fit_reg=False, legend=True, legend_out=True)
