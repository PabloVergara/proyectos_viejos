# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Avlapd= [25400255,22008960]
#25.400.255	22.008.960
#CECEpd= [7004842, 3847517]
Continentalpd=[34038164,33330186]
HDIpd=[13464540,16054928]
#34.038.164	33.330.186
COFACEpd=[12099800,12169588]
#12.099.800	12.169.588

Solunionpd=[7876329,4500586]
CECEpd= [5296369,7004842]
#7.876.329	4.500.58
ORSANpd=[2226781,1903]
#2.226.781	1.903

# %%
colors = 'blue', 'gold', 'lightcoral', 'lightskyblue', 'red', 'green', 'cyan'
# Data 2018
labels = 'Avla', 'Continental', 'HDI', 'COFACE', 'Solunion', 'CECE', 'ORSAN'
size1 = [25400255, 34038164, 13464540, 12099800, 7876329, 5296369, 2226781 ]
# Data 2017
size2 = [22008960, 33330186, 16054928, 12169588, 4500586, 7004842, 1903   ]
explode = (0.1, 0, 0, 0, 0 ,0 ,0) 

# Plot 1
#plt.subplot(1, 2, 1,)
plt.pie(size1, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
plt.xlabel('2018')
plt.axis('equal')
#plot 2
#plt.subplot(1, 2, 2)
plt.pie(size2, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
plt.xlabel('2017')
plt.axis('equal')
plt.show()

# %%
fig1, ax1 = plt.subplots()
fig1.set_figheight(6)
fig1.set_figwidth(6)
ax1.pie(size1, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.xlabel('Pastel 2018')
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
fig1, ax1 = plt.subplots()
fig1.set_figheight(6)
fig1.set_figwidth(6)
ax1.pie(size2, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.xlabel('Pastel 2017')
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
print(sum(size2)-sum(size1))
# Out:
# -5331245

# %%
5000000000/27500
# Out:
# 181818.18181818182
